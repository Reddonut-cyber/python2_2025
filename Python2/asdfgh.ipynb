# %%
def custom_generator(data, element=0):
    for item in data:
        yield element, item
        element += 1
        
for item in custom_generator(['a', 'b', 'c']):
    print(item)
# Out:
# (0, 'a')
# (1, 'b')
# (2, 'c')
